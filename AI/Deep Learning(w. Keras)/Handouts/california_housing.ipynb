# %% [markdown]
# # Get Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_california_housing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
dataset = fetch_california_housing()
x = dataset.data
y = dataset.target
x_label = dataset.feature_names
y_label = dataset.target_names

# %%
print(dataset.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block group
#         - HouseAge      median house age in block group
#         - AveRooms      average number of rooms per household
#         - AveBedrms     average number of bedrooms per household
#         - Population    block group population
#         - AveOccup      average number of household members
#         - Latitude      block group latitude
#         - Longitude     block group longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# An household is a group of people residing within a home. Since the average
# number of rooms and bedrooms in this dataset are provided per household, these
# columns may take surpinsingly large values for block groups with few households
# and many empty houses, such as vacation resorts.
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297

# %%
raw_x = pd.DataFrame(x, columns=x_label)
raw_x
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
raw_x.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# 25%        2.429741     33.930000   -121.800000
# 50%        2.818116     34.260000   -118.490000
# 75%        3.282261     37.710000   -118.010000
# max     1243.333333     41.950000   -114.310000

# %%
raw_y = pd.DataFrame(y, columns=y_label)
raw_y
# Out:
#        MedHouseVal
# 0            4.526
# 1            3.585
# 2            3.521
# 3            3.413
# 4            3.422
# ...            ...
# 20635        0.781
# 20636        0.771
# 20637        0.923
# 20638        0.847
# 20639        0.894
#
# [20640 rows x 1 columns]

# %%
raw_y.describe()
# Out:
#         MedHouseVal
# count  20640.000000
# mean       2.068558
# std        1.153956
# min        0.149990
# 25%        1.196000
# 50%        1.797000
# 75%        2.647250
# max        5.000010

# %%
raw_x.plot.box()
# Out:
# <AxesSubplot:>

# %%
raw_y.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Cleaning Data

# %%
x_scaler = MinMaxScaler()
scaled_x = x_scaler.fit_transform(raw_x)
scaled_x = pd.DataFrame(scaled_x, columns=x_label)

# %%
scaled_x.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       0.232464      0.541951      0.032488      0.022629      0.039869
# std        0.131020      0.246776      0.017539      0.014049      0.031740
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.142308      0.333333      0.025482      0.019943      0.021974
# 50%        0.209301      0.549020      0.031071      0.021209      0.032596
# 75%        0.292641      0.705882      0.036907      0.022713      0.048264
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       0.001914      0.328572      0.476125
# std        0.008358      0.226988      0.199555
# min        0.000000      0.000000      0.000000
# 25%        0.001398      0.147715      0.253984
# 50%        0.001711      0.182784      0.583665
# 75%        0.002084      0.549416      0.631474
# max        1.000000      1.000000      1.000000

# %%
y_scaler = MinMaxScaler()
scaled_y = y_scaler.fit_transform(raw_y)
scaled_y = pd.DataFrame(scaled_y, columns=y_label)

# %%
scaled_y.describe()
# Out:
#         MedHouseVal
# count  20640.000000
# mean       0.395579
# std        0.237928
# min        0.000000
# 25%        0.215671
# 50%        0.339588
# 75%        0.514897
# max        1.000000

# %%
scaled_x.plot.box()
# Out:
# <AxesSubplot:>

# %%
scaled_y.plot.box()
# Out:
# <AxesSubplot:>

# %%
x_train, x_test, y_train, y_test = train_test_split(scaled_x, scaled_y, test_size=0.3, random_state=5)

# %%
# x_train
# x_test
# y_train
# y_test
x_train.describe()
# x_test.describe()
# y_train.describe()
# y_test.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  14448.000000  14448.000000  14448.000000  14448.000000  14448.000000
# mean       0.231968      0.541279      0.032456      0.022654      0.040027
# std        0.129566      0.246965      0.018481      0.014784      0.030934
# min        0.000000      0.000000      0.000303      0.000000      0.000000
# 25%        0.141770      0.333333      0.025403      0.019941      0.022086
# 50%        0.209487      0.549020      0.031040      0.021216      0.032652
# 75%        0.293624      0.705882      0.036902      0.022723      0.048460
# max        1.000000      1.000000      1.000000      1.000000      0.456907
#
#            AveOccup      Latitude     Longitude
# count  14448.000000  14448.000000  14448.000000
# mean       0.001930      0.328878      0.476361
# std        0.009393      0.227308      0.199559
# min        0.000000      0.000000      0.000000
# 25%        0.001397      0.147715      0.254980
# 50%        0.001711      0.182784      0.583665
# 75%        0.002091      0.550478      0.631474
# max        1.000000      1.000000      1.000000

# %% [markdown]
# # Train Model

# %%
model = Sequential()
model.add(Dense(200, activation="relu", input_dim=8))
model.add(Dense(1000, activation="relu"))
model.add(Dense(1, activation="linear"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 200)               1800
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              201000
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 1001
# =================================================================
# Total params: 203,801
# Trainable params: 203,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="sgd", loss="mse", metrics=["accuracy"])

# %%
history = model.fit(x_train, y_train, batch_size=64, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0193 - accuracy: 0.0399
# Epoch 2/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0193 - accuracy: 0.0400
# Epoch 3/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0193 - accuracy: 0.0400
# Epoch 4/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0193 - accuracy: 0.0401
# Epoch 5/100
# 226/226 [==============================] - 0s 906us/step - loss: 0.0193 - accuracy: 0.0401
# Epoch 6/100
# 226/226 [==============================] - 0s 891us/step - loss: 0.0193 - accuracy: 0.0401
# Epoch 7/100
# 226/226 [==============================] - 0s 891us/step - loss: 0.0193 - accuracy: 0.0401
# Epoch 8/100
# 226/226 [==============================] - 0s 911us/step - loss: 0.0193 - accuracy: 0.0403
# Epoch 9/100
# 226/226 [==============================] - 0s 892us/step - loss: 0.0192 - accuracy: 0.0401
# Epoch 10/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0192 - accuracy: 0.0401
# Epoch 11/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0193 - accuracy: 0.0401
# Epoch 12/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0192 - accuracy: 0.0401
# Epoch 13/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0192 - accuracy: 0.0401
# Epoch 14/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0192 - accuracy: 0.0401
# Epoch 15/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0192 - accuracy: 0.0400
# Epoch 16/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0192 - accuracy: 0.0401
# Epoch 17/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0192 - accuracy: 0.0403
# Epoch 18/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0192 - accuracy: 0.0400
# Epoch 19/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0192 - accuracy: 0.0402
# Epoch 20/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0192 - accuracy: 0.0401
# Epoch 21/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0192 - accuracy: 0.0404
# Epoch 22/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0192 - accuracy: 0.0402
# Epoch 23/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0191 - accuracy: 0.0401
# Epoch 24/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0191 - accuracy: 0.0403
# Epoch 25/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0191 - accuracy: 0.0403
# Epoch 26/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0191 - accuracy: 0.0403
# Epoch 27/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0191 - accuracy: 0.0401
# Epoch 28/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0191 - accuracy: 0.0402
# Epoch 29/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0191 - accuracy: 0.0401
# Epoch 30/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0191 - accuracy: 0.0403
# Epoch 31/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0191 - accuracy: 0.0401
# Epoch 32/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0191 - accuracy: 0.0402
# Epoch 33/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0191 - accuracy: 0.0403
# Epoch 34/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0191 - accuracy: 0.0401
# Epoch 35/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0191 - accuracy: 0.0401
# Epoch 36/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.0400
# Epoch 37/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0191 - accuracy: 0.0402
# Epoch 38/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0191 - accuracy: 0.0403
# Epoch 39/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.0404
# Epoch 40/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.0401
# Epoch 41/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.0403
# Epoch 42/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.0402
# Epoch 43/100
# 226/226 [==============================] - 0s 2ms/step - loss: 0.0190 - accuracy: 0.0403
# Epoch 44/100
# 226/226 [==============================] - 0s 2ms/step - loss: 0.0190 - accuracy: 0.0402
# Epoch 45/100
# 226/226 [==============================] - 0s 2ms/step - loss: 0.0190 - accuracy: 0.0401
# Epoch 46/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.0401
# Epoch 47/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.0401
# Epoch 48/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.0403
# Epoch 49/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.0401
# Epoch 50/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.0404
# Epoch 51/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.0402
# Epoch 52/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.0401
# Epoch 53/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.0404
# Epoch 54/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0189 - accuracy: 0.0404
# Epoch 55/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0189 - accuracy: 0.0402
# Epoch 56/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0189 - accuracy: 0.0403
# Epoch 57/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0189 - accuracy: 0.0404
# Epoch 58/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0189 - accuracy: 0.0402
# Epoch 59/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0189 - accuracy: 0.0404
# Epoch 60/100
# 226/226 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 0.0404
# Epoch 61/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0189 - accuracy: 0.0402
# Epoch 62/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0189 - accuracy: 0.0403
# Epoch 63/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0189 - accuracy: 0.0402
# Epoch 64/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0189 - accuracy: 0.0402
# Epoch 65/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0189 - accuracy: 0.0404
# Epoch 66/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0189 - accuracy: 0.0404
# Epoch 67/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0189 - accuracy: 0.0401
# Epoch 68/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.0403
# Epoch 69/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.0404
# Epoch 70/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.0404
# Epoch 71/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.0401
# Epoch 72/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.0402
# Epoch 73/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.0401
# Epoch 74/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.0401
# Epoch 75/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.0404
# Epoch 76/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.0402
# Epoch 77/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.0402
# Epoch 78/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.0401
# Epoch 79/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.0404
# Epoch 80/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.0401
# Epoch 81/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.0403
# Epoch 82/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.0404
# Epoch 83/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.0401
# Epoch 84/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0187 - accuracy: 0.0404
# Epoch 85/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.0402
# Epoch 86/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0187 - accuracy: 0.0401
# Epoch 87/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.0404
# Epoch 88/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0187 - accuracy: 0.0402
# Epoch 89/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0187 - accuracy: 0.0404
# Epoch 90/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0187 - accuracy: 0.0403
# Epoch 91/100
# 226/226 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 0.0402
# Epoch 92/100
# 226/226 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 0.0403
# Epoch 93/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0187 - accuracy: 0.0404
# Epoch 94/100
# 226/226 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 0.0404
# Epoch 95/100
# 226/226 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 0.0403
# Epoch 96/100
# 226/226 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 0.0403
# Epoch 97/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0187 - accuracy: 0.0405
# Epoch 98/100
# 226/226 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 0.0403
# Epoch 99/100
# 226/226 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 0.0405
# Epoch 100/100
# 226/226 [==============================] - 0s 1ms/step - loss: 0.0187 - accuracy: 0.0404

# %%
fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history["loss"], "r")
acc_ax.plot(history.history["accuracy"], "g")
plt.show()

# %% [markdown]
# # Evaluate Model

# %%
score = model.evaluate(x_test, y_test, verbose=1)
print("test loss:", score[0])
print("test acc:", score[1])
# Out:
#   1/194 [..............................] - ETA: 0s - loss: 0.0145 - accuracy: 0.0312WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 194/194 [==============================] - 0s 558us/step - loss: 0.0194 - accuracy: 0.0417
# test loss: 0.019421948119997978
# test acc: 0.0416666679084301

# %%
y_pred = model.predict(x_test)

# %%
plt.plot(y_pred, y_test, "b,")
plt.plot([0, 1], [0, 1], "r--")

plt.grid()
plt.show()

# %%
inversed_pred = y_scaler.inverse_transform(y_pred)
inversed_actual = y_scaler.inverse_transform(y_test)

# %%
plt.plot(inversed_pred, inversed_actual, "b,")
plt.plot([0, 5], [0, 5], "r--")

plt.grid()
plt.show()
